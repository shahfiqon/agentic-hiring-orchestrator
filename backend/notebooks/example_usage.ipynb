# %% [markdown]
# # Agentic Hiring Orchestrator - Example Usage
#
# This notebook demonstrates how to use the agentic hiring evaluation system interactively.
#
# ## Setup
#
# Make sure you have:
# 1. Installed dependencies: `pdm install --dev --with notebooks`
# 2. Configured your `.env` file with LLM provider settings
# 3. Started your LLM server (if using llama.cpp)

# %%
# Import necessary modules
import sys
from pathlib import Path

# Add parent directory to path to import src modules
sys.path.insert(0, str(Path.cwd().parent))

from src.config import get_settings

# Load configuration
settings = get_settings()
print(f"LLM Provider: {settings.llm_provider}")
print(f"Temperature: {settings.temperature}")
print(f"Working Memory: {settings.enable_working_memory}")

# %% [markdown]
# ## Sample Candidate Data
#
# Define candidate information for evaluation.

# %%
sample_candidate = {
    "name": "Jane Doe",
    "role": "Senior Backend Engineer",
    "resume": """Experienced backend engineer with 5+ years in Python and distributed systems.
    Strong expertise in FastAPI, PostgreSQL, and cloud architecture.
    Led migration of monolith to microservices serving 1M+ users.""",
    "experience_years": 5,
    "skills": ["Python", "FastAPI", "PostgreSQL", "Docker", "Kubernetes", "Redis"]
}

print(f"Candidate: {sample_candidate['name']}")
print(f"Position: {sample_candidate['role']}")
print(f"Skills: {', '.join(sample_candidate['skills'])}")

# %% [markdown]
# ## Run Evaluation Pipeline
#
# TODO: Execute the evaluation graph once implemented in `src/graph/`

# %%
# TODO: Uncomment when graph is implemented
# from src.graph import create_graph
# 
# graph = create_graph()
# result = await graph.ainvoke(sample_candidate)
# 
# print("Evaluation Result:")
# print(result)

print("Graph implementation pending - see src/graph/")

# %% [markdown]
# ## Analyze Results
#
# TODO: Add result visualization and analysis cells

# %%
# TODO: Add visualization code
# import matplotlib.pyplot as plt
# import pandas as pd
# 
# Visualize scores, rubric breakdowns, etc.

print("Results visualization to be added")
